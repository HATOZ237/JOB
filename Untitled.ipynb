# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import pickle

# %%
name = ['Breast_cancer', 'Opt_digits', 'Iris', "Wine"]
filename = "RAND-TAB-SVC"
infile = open(filename,'rb')
new_dict = pickle.load(infile)
infile.close()

# %%
# %matplotlib
plt.figure(figsize=(16,13))
sns.set_theme()
plt.suptitle("RF")
'''for i in range(len(names)):
    liste = [0 for n in range(10)]
    plt.subplot(2, 2, i+1)
    for k in range(10):
        liste[k]  = sorted(new_dict[names[i]][k]["mean_test_score"])
    liste = np.array(liste)
    mean_train = np.mean(liste, axis=0)
    std_train = np.std(liste, axis=0)
    plt.plot(np.arange(1,2001), mean_train, label = "Random Search")
    plt.xscale("log")
    plt.title(f"Data :{names[i]}")
    plt.xlabel("Nombre d'evaluations")
    plt.ylabel("Score d'optimisation")
    plt.legend()'''

names = ['load_breast_cancer', 'load_digits', 'load_iris', "load_wine"]
filename = "CMA-TAB-RF"
infile = open(filename,'rb')
dico = pickle.load(infile)
infile.close()
for k in range(len(names)):
    plt.subplot(2,2,k+1)
    liste = dico[names[k]]
    main_train = np.mean(liste, axis= 1)
    std_train = np.std(liste, axis = 1)
    plt.plot(np.arange(1,11)*200, main_train,label = "CMA-ES", lw = 2)
    plt.fill_between(np.arange(1,11)*200, main_train-std_train,main_train+std_train, alpha = 0.1)
    plt.xscale("log")
    plt.title(f"Data :{names[k]}")
    plt.xlabel("Nombre d'evaluations")
    plt.ylabel("Score d'optimisation")
    plt.legend()

filename = "RAN-TAB-RF"
infile = open(filename,'rb')
dico = pickle.load(infile)
infile.close()
for k in range(len(names)):
    plt.subplot(2,2,k+1)
    liste = dico[name[k]]
    main_train = np.mean(liste, axis= 1)
    std_train = np.std(liste, axis = 1)
    plt.plot(np.arange(1,11)*200, main_train,label = "Random Search",lw =2)
    plt.fill_between(np.arange(1,11)*200, main_train-std_train,main_train+std_train, alpha = 0.1)
    plt.xscale("log")
    plt.legend()

filename = "ONE-TAB-RF"
infile = open(filename,'rb')
dico = pickle.load(infile)
infile.close()
for k in range(len(names)):
    plt.subplot(2,2,k+1)
    liste = dico[names[k]]
    main_train = np.mean(liste, axis= 0)
    std_train = np.std(liste, axis = 0)
    plt.plot(np.arange(1,11)*200, main_train,label = "OneFifth", lw = 2)
    plt.fill_between(np.arange(1,11)*200, main_train-std_train,main_train+std_train, alpha = 0.1)
    plt.legend()
plt.tight_layout()
# Out:
# Using matplotlib backend: Qt5Agg
# <ipython-input-25-5542fafa3cc7>:43: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:43: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:43: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:43: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:57: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:57: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:57: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)
# <ipython-input-25-5542fafa3cc7>:57: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,2,k+1)

# %%
plt.plot(sorted(new_dict["Iris"][8]["mean_test_score"]))
plt.xscale("log")

# %%
def sorted(liste):
    first = liste[0]
    for i in range(len(liste)):
        if first < liste[i]:
            first = liste[i]
        if first >= liste[i]:
            liste[i] = first
    return liste

# %%
pd.read_csv("RANDSEARCH-RF-2000")
# Out:
#         Unnamed: 0  Breast_cancer  Opt_digits       Iris       Wine
# 0     n_estimators      17.000000   89.000000  10.000000  12.000000
# 1      max_samples       0.666333    0.888111   0.555444   0.666333
# 2     max_features       0.001000    0.111889   0.888111   0.001000
# 3   max_test_score       0.972028    0.977778   0.973684   0.933333
# 4  max_train_score       0.964789    0.973274   0.982219   1.000000
# 5       test_score       0.962238    0.969111   0.968421   0.913333
# 6         std_test       0.009988    0.005661   0.015789   0.018459
# 7      train_score       0.959624    0.972606   0.975913   0.993232
# 8        std_train       0.002300    0.000617   0.004128   0.002257
# 9             time      58.501899  104.079106  48.000716  48.828948

# %%
filename = "CMA-TAB-RF"
infile = open(filename,'rb')
dico = pickle.load(infile)
infile.close()

# %%
dico
# Out:
# {'load_breast_cancer': [[0.9553990610328639,
#    0.948356807511737,
#    0.9436619718309859,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9413145539906104,
#    0.9483568075117371,
#    0.9413145539906104,
#    0.948356807511737,
#    0.9483568075117371],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.948356807511737,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9483568075117371,
#    0.9413145539906104,
#    0.948356807511737,
#    0.9483568075117371],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.948356807511737,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9483568075117371,
#    0.9460093896713615,
#    0.9507042253521126,
#    0.9507042253521126],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.948356807511737,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9460093896713615,
#    0.9507042253521126,
#    0.9507042253521126],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.9507042253521126],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.9530516431924884],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924884],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924884],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924884],
#   [0.9553990610328639,
#    0.9483568075117371,
#    0.9507042253521126,
#    0.948356807511737,
#    0.9507042253521126,
#    0.9530516431924881,
#    0.9530516431924881,
#    0.9507042253521126,
#    0.9507042253521126,
#    0.9530516431924884]],
#  'load_digits': [[0.9606533036377134,
#    0.9665924276169265,
#    0.9717891610987378,
#    0.9740163325909429,
#    0.9658500371195249,
#    0.9688195991091314,
#    0.9680772086117297,
#    0.9710467706013363,
#    0.9651076466221232,
#    0.9665924276169265],
#   [0.9658500371195249,
#    0.9665924276169265,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9658500371195249,
#    0.9688195991091314,
#    0.9703043801039346,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.9673348181143281,
#    0.9665924276169265,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9658500371195249,
#    0.969561989606533,
#    0.9703043801039346,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.9673348181143281,
#    0.9665924276169265,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9658500371195249,
#    0.969561989606533,
#    0.9703043801039346,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.9688195991091314,
#    0.9665924276169265,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.969561989606533,
#    0.9710467706013363,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.9688195991091314,
#    0.9665924276169265,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.969561989606533,
#    0.9710467706013363,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.9688195991091314,
#    0.969561989606533,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.969561989606533,
#    0.9717891610987378,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.969561989606533,
#    0.969561989606533,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.9710467706013363,
#    0.9717891610987378,
#    0.9710467706013363,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.969561989606533,
#    0.9732739420935412,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.9710467706013363,
#    0.9717891610987378,
#    0.971789161098738,
#    0.9725315515961396,
#    0.9703043801039346],
#   [0.969561989606533,
#    0.9732739420935412,
#    0.9747587230883444,
#    0.9740163325909429,
#    0.9703043801039347,
#    0.9710467706013363,
#    0.9717891610987378,
#    0.971789161098738,
#    0.9725315515961396,
#    0.9703043801039346]],
#  'load_iris': [[0.9551920341394026,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9551920341394026,
#    0.9551920341394026,
#    0.9551920341394026,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9551920341394026,
#    0.9642010431484116,
#    0.9551920341394026,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116],
#   [0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116,
#    0.9732100521574205,
#    0.9732100521574205,
#    0.9642010431484116,
#    0.9642010431484116]],
#  'load_wine': [[0.9772727272727272,
#    0.9698653198653199,
#    0.9700336700336701,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.962121212121212,
#    0.9848484848484849,
#    0.9696969696969697,
#    0.9696969696969697,
#    0.9698653198653199],
#   [0.9848484848484849,
#    0.9698653198653199,
#    0.9848484848484849,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9774410774410774,
#    0.9848484848484849,
#    0.9696969696969697,
#    0.9774410774410774,
#    0.9698653198653199],
#   [0.9848484848484849,
#    0.9698653198653199,
#    0.9848484848484849,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9774410774410774,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9774410774410774,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9850168350168351,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9850168350168351,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    1.0,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9850168350168351,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    1.0,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9848484848484849,
#    0.9850168350168351,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    1.0,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849],
#   [0.9848484848484849,
#    0.9774410774410774,
#    0.9924242424242425,
#    1.0,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849,
#    0.9924242424242425,
#    0.9850168350168351,
#    0.9848484848484849]]}

# %%
np.arange(1,11)*200
# Out:
# array([ 200,  400,  600,  800, 1000, 1200, 1400, 1600, 1800, 2000])

# %%
pat  = pd.read_pickle("GRIDRESULTS-SGD")
pat = pd.DataFrame(pat[name[1]].to_dict())
pat = pat[pat["param_learning_rate"] == "constant"]
pat = pat[pat["param_loss"] == "modified_huber"]
pat = pat[['param_alpha', 'param_l1_ratio', "mean_test_score"]]
pat = pat.round(decimals=6)
pat = pat.pivot('param_alpha', 'param_l1_ratio', "mean_test_score")
plt.figure(figsize=(15, 12))
sns.heatmap(pat,cmap='rainbow_r',linewidths=.1)
plt.tight_layout()

# %%
#pat = pd.DataFrame(pat[name[1]].to_dict())
pat = pat[pat["param_learning_rate"] == "invscaling"]
pat = pat[pat["param_loss"] == "log"]
pat = pat[['param_alpha', 'param_l1_ratio', "mean_test_score"]]
pat = pat.round(decimals=6)
pat = pat.pivot('param_alpha', 'param_l1_ratio', "mean_test_score")
plt.figure(figsize=(15, 12))
sns.heatmap(pat,cmap='rainbow_r',linewidths=.1)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'param_learning_rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-8a2b67267919> in <module>
#       1 #pat = pd.DataFrame(pat[name[1]].to_dict())
# ----> 2 pat = pat[pat["param_learning_rate"] == "invscaling"]
#       3 pat = pat[pat["param_loss"] == "log"]
#       4 pat = pat[['param_alpha', 'param_l1_ratio', "mean_test_score"]]
#       5 pat = pat.round(decimals=6)
#
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# H:\Nouveau dossier (2)\Nouveau dossier\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'param_learning_rate'

# %%
#pat.dropna(axis=0)
#pat

#pat.dropna(axis=1)

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
x = np.linspace(0,1, 100)
f = lambda x: 10**(-4*x+4)
liste = list(map(f, x))

# %%
liste
# Out:
# [10000.0,
#  9111.627561154895,
#  8302.175681319744,
#  7564.633275546291,
#  6892.612104349695,
#  6280.291441834253,
#  5722.3676593502205,
#  5214.008287999684,
#  4750.810162102798,
#  4328.761281083057,
#  3944.206059437656,
#  3593.813663804626,
#  3274.5491628777286,
#  2983.64724028334,
#  2718.58824273294,
#  2477.0763559917114,
#  2257.019719633919,
#  2056.5123083486515,
#  1873.817422860383,
#  1707.3526474706905,
#  1555.6761439304723,
#  1417.4741629268049,
#  1291.549665014884,
#  1176.811952434998,
#  1072.2672220103232,
#  977.0099572992247,
#  890.2150854450383,
#  811.1308307896873,
#  739.0722033525775,
#  673.4150657750821,
#  613.5907273413176,
#  559.0810182512223,
#  509.4138014816375,
#  464.15888336127773,
#  422.9242874389499,
#  385.3528593710527,
#  351.1191734215131,
#  319.92671377973846,
#  291.50530628251755,
#  265.6087782946684,
#  242.0128264794381,
#  220.51307399030458,
#  200.92330025650458,
#  183.07382802953677,
#  166.81005372000593,
#  151.99110829529332,
#  138.48863713938718,
#  126.18568830660197,
#  114.97569953977356,
#  104.7615752789664,
#  95.45484566618337,
#  86.97490026177826,
#  79.24828983539169,
#  72.20809018385464,
#  65.79332246575676,
#  59.94842503189409,
#  54.62277217684337,
#  49.77023564332109,
#  45.34878508128582,
#  41.320124001153346,
#  37.64935806792467,
#  34.30469286314916,
#  31.25715849688235,
#  28.48035868435799,
#  25.950242113997348,
#  23.644894126454073,
#  21.54434690031882,
#  19.630406500402703,
#  17.886495290574334,
#  16.297508346206435,
#  14.849682622544636,
#  13.530477745798061,
#  12.32846739442066,
#  11.233240329780266,
#  10.235310218990259,
#  9.32603346883219,
#  8.497534359086439,
#  7.742636826811269,
#  7.054802310718638,
#  6.4280731172843195,
#  5.857020818056661,
#  5.336699231206307,
#  4.862601580065348,
#  4.430621457583878,
#  4.037017258596554,
#  3.6783797718286304,
#  3.351602650938841,
#  3.0538555088334123,
#  2.782559402207123,
#  2.5353644939701088,
#  2.310129700083158,
#  2.1049041445120196,
#  1.9179102616724868,
#  1.747528400007683,
#  1.5922827933410906,
#  1.4508287784959386,
#  1.3219411484660286,
#  1.2045035402587811,
#  1.0974987654930557,
#  1.0]
